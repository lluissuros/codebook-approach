# %% [markdown]
# # 1) Download sounds from a id list
#
# ## Also download all features, BUT remember it is not frame-based, its the statistical aggregattion
#
# This notebook includes the code to create the collection of sounds that will later be used as source material for our audio mosaicing application. The collection of sounds is created by defining a number of queries to be performed using the Freesound API and concatenanting the results of each query. A number of metadata fields are stored for each sound in the collection and saved into a Pandas DataFrame object and CSV file in disk. For each sound in the collection, we also download an OGG preview and store it in disk.
#
# This notebook uses the `freesound` Python package for interacting with the Freesound API. The source code for this package can be found here: https://github.com/mtg/freesound-python. In this repository you'll find a Python script with [examples](https://github.com/MTG/freesound-python/blob/master/examples.py) to learn how to interact with the API. Nevertheless, if you are further interested in the Freesound API, check the [API documentation](http://freesound.org/docs/api/) which provides more information.
#
# **NOTE**: A Freesound API key is provided in this notebook, but you should make a Freesound account and get your own key. You can get a key here: https://freesound.org/apiv2/apply/

# %%
import os
import pandas as pd
import numpy as np
#import freesound # pip install --user git+https://github.com/MTG/freesound-python
import freesound_lluis as freesound # this is my own version, until I can use the PR I made
from IPython.display import display

FREESOUND_API_KEY = 's9xV21k899aPetFLLLj7IQjq2hCprXG0IqymUEy1'  # my api key
FILES_DIR = 'files'  # Place where to store the downloaded diles. Will be relative to the current folder.
DATAFRAME_FILENAME = 'dataframe.csv'  # File where we'll store the metadata of our sounds collection
FREESOUND_STORE_METADATA_FIELDS = ['id', 'name', 'username', 'previews', 'license', 'tags']  # Freesound metadata properties to store

freesound_client = freesound.FreesoundClient()
freesound_client.set_token(FREESOUND_API_KEY)
if not os.path.exists(FILES_DIR): os.mkdir(FILES_DIR)

# %%
# Define some util functions

def query_freesound(query, filter, num_results=10):
    """Queries freesound with the given query and filter values.
    If no filter is given, a default filter is added to only get sounds shorter than 30 seconds.
    """
    if filter is None:
        filter = 'duration:[0 TO 30]'  # Set default filter
    pager = freesound_client.text_search(
        query = query,
        filter = filter,
        fields = ','.join(FREESOUND_STORE_METADATA_FIELDS),
        group_by_pack = 1,
        page_size = num_results
    )
    return [sound for sound in pager]

def retrieve_sound(freesound_id):
    "retrives sound by id --> https://github.com/MTG/freesound-python/blob/master/freesound.py"
    return freesound_client.get_sound(freesound_id)
    
    
def retrieve_sound_preview(sound, directory):
    """Download the high-quality OGG sound preview of a given Freesound sound object to the given directory.
    """
    return freesound.FSRequest.retrieve(
        sound.previews.preview_hq_ogg,
        freesound_client,
        os.path.join(directory, sound.previews.preview_hq_ogg.split('/')[-1])
    )

def retrieve_analysis_by_frame(sound, features_to_use):
    descriptors = ",".join(features_to_use)
    return sound.get_analysis(descriptors=descriptors)

def make_record(sound, file_path = "files/"): 
    """Create a dictionary with the metadata that we want to store for each sound.
    """
    record = {key: sound.as_dict()[key] for key in FREESOUND_STORE_METADATA_FIELDS}
    del record['previews']  # Don't store previews dict in record
    record['freesound_id'] = record['id']  # Rename 'id' to 'freesound_id'
    record['path'] = file_path + sound.previews.preview_hq_ogg.split("/")[-1]  # Store path of downloaded file
    return record

# %%
#ROUTES

DOWNLOADED_PREVIEWS_DIR = FILES_DIR + '/previews/'
DATAFRAME_CSV_FILENAME = 'dataframes/multiple_events.csv'

# %% [raw]
# # TODO: I think Idont need this one ?
#
#
#
# #MY OWN CONTRIBUTION: download by ids
#
# problems=[]
#
#
# def build_sound_collection(freesound_ids, features_to_use, sound_files_path, dataframe_filename):
#
#     anal_by_id = {}
#     sounds = []
#     records=[]
#
#     for count, freesound_id in enumerate(freesound_ids):
#         sound = retrieve_sound(freesound_id)
#         sounds.append(sound)
#         print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(freesound_ids)))
#         retrieve_sound_preview(sound, sound_files_path) # Download the sounds and save them to FILES_DIR folder
#         '''test_anal = retrieve_analysis_by_frame(sound, features_to_use)
#         anal_by_id[sound.id] = test_anal'''
#
#         #records = [make_record(s, sound_files_path) for s in sounds]
#
#
#     return sounds
#
#     # ==> we want to save an .npy file for each freesound_id
#
#
#
#     # Do all queries and concatenate soundthe results in a single list of sounds
#     #sounds = sum([query_freesound(query['query'], query['filter'], query['num_results']) for query in freesound_queries],[])
#
#
#     '''    for count, sound in enumerate(sounds):
#         print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(sounds)))
#         retrieve_sound_preview(sound, sound_files_path)
#
#     # Make a Pandas DataFrame with the metadata of our sound collection and save it
#     df =  pd.DataFrame([make_pandas_record(s, sound_files_path) for s in sounds])
#     df.to_csv(dataframe_filename)
#     print('Saved DataFrame with {0} entries! {1}'.format(len(df), dataframe_filename))
#
#     # Show the contents of our DataFrame (the metadata of our source collection)
#     return df, sounds'''
#
#
#
#
#
#
# freesound_ids = [415297]
# #features_to_use = ['lowlevel.mfcc']
# features_to_use = []
#
#
# #df, sounds = build_sound_collection(freesound_queries_music_loops, DOWNLOADED_PREVIEWS_DIR, DATAFRAME_CSV_FILENAME_MUSIC_LOOPS)
# #df.head(5)
#
# sounds = build_sound_collection(freesound_ids, features_to_use, DOWNLOADED_PREVIEWS_DIR, DATAFRAME_CSV_FILENAME)
#
# #download problems
# #print("try again, with the problems")
# #records_problems = build_sound_collection(problems, features_to_use, DOWNLOADED_PREVIEWS_DIR, DATAFRAME_CSV_FILENAME)
# #records = records + records_problems

# %%
#MY OWN CONTRIBUTION: download by ids

# Build our collection of sounds
DOWNLOADED_PREVIEWS_DIR = FILES_DIR + '/previews/'
DATAFRAME_CSV_FILENAME = 'dataframes/multiple_events.csv'

problems=[]

def build_sound_collection(freesound_ids, features_to_use, sound_files_path, dataframe_filename):
    
    anal_by_id = {}
    sounds = []
    records = []
    
    for count, freesound_id in enumerate(freesound_ids):
        try:
            sound = retrieve_sound(freesound_id)
            sounds.append(sound)
            print('Downloading sound with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(freesound_ids)))
            retrieve_sound_preview(sound, sound_files_path) # Download the sounds and save them to FILES_DIR folder
            '''test_anal = retrieve_analysis_by_frame(sound, features_to_use)
            anal_by_id[sound.id] = test_anal'''

            records = [make_record(s, sound_files_path) for s in sounds]
        except: 
            print("====== problem with", freesound_id)
            problems.append(freesound_id)
    
    # ==> we want to save an .npy file for each freesound_id
    
    # Do all queries and concatenate the results in a single list of sounds
    #sounds = sum([query_freesound(query['query'], query['filter'], query['num_results']) for query in freesound_queries],[])

    return records, sounds


''' === available lowlevel features for frame analysis: ====
['barkbands_spread', 'spectral_kurtosis', 'scvalleys', 'erb_bands', 'frequency_bands', 'spectral_flatness_db', 
'pitch', 'average_loudness', 'spectral_centroid', 'dissonance', 'spectral_crest', 'spectral_skewness', 
'pitch_instantaneous_confidence', 'barkbands', 'silence_rate_20dB', 'spectral_strongpeak', 'startFrame', 'stopFrame',
'silence_rate_30dB', 'pitch_salience', 'spectral_energyband_high', 'silence_rate_60dB',
'spectral_energyband_middle_high', 'zerocrossingrate', 'barkbands_skewness', 'spectral_entropy', 'hfc', 
'spectral_rolloff', 'spectral_contrast', 'spectral_flux', 'spectral_energy', 'spectral_rms', 'spectral_decrease', 
'spectral_spread', 'spectral_energyband_middle_low', 'barkbands_kurtosis', 'spectral_energyband_low', 
'spectral_complexity', 'mfcc', 'gfcc']
'''


nature_ids = [415297,403357,41135,58155,403358,428266,403359,403357,405373,397092,148870,51667,51643,136971,136692,148879,136691,148877,161013,231275,263810,53469,17736,424692,265034,7744,79232,105383,194993,223277,174624,206154,98779,275468,234107,97389,171473,236952,95892,207473,147182,400384,432846,434352,394959,402547,179900,267464,250725,86567,402801,317130,33256,169693,251635,367328,428266]
human_ids = [424844,412776,278295,192529,186253,46328,46325,94149,58334,259168,350324,132900,251473,60118,58168,44478,136052,341874,57744,55060,122814,401539,401993,130597,424844,72009,115088,205463,249776,75277,241698,69823,138469,240725,80980,101792,56730,210093,192178,17093,191337,365220,44311,371339,397336,161018,153425,239299,233261,169944,340747,329568,387459,407207,387460,397667,45352,31169,25270,32868,46228,49482,42811,39843,113148,407292,334980,211945,457258,32380,350655,383879,25450,326244,259630,203305,233018,407735,327497,366843,365965,145267,332183,369871,407499,389592,344238,24089,324427,81782,201942,346457,278295,192529,186253]
freesound_ids = nature_ids + human_ids


#features_to_use = ['lowlevel.mfcc'] 
features_to_use = [] 

#df, sounds = build_sound_collection(freesound_queries_music_loops, DOWNLOADED_PREVIEWS_DIR, DATAFRAME_CSV_FILENAME_MUSIC_LOOPS)
#df.head(5)

records, sounds = build_sound_collection(freesound_ids, features_to_use, DOWNLOADED_PREVIEWS_DIR, DATAFRAME_CSV_FILENAME)
#download problems
print("try again, with the problems")
records_problems, sounds_problems = build_sound_collection(problems, features_to_use, DOWNLOADED_PREVIEWS_DIR, DATAFRAME_CSV_FILENAME)
records = records + records_problems
sounds = sounds + sounds_problems
# Out:
# Downloading sound with id 415297 [1/154]
# Downloading sound with id 403357 [2/154]
# Downloading sound with id 41135 [3/154]
# Downloading sound with id 58155 [4/154]
# Downloading sound with id 403358 [5/154]
# Downloading sound with id 428266 [6/154]
# Downloading sound with id 403359 [7/154]
# Downloading sound with id 403357 [8/154]
# Downloading sound with id 405373 [9/154]
# Downloading sound with id 397092 [10/154]
# Downloading sound with id 148870 [11/154]
# ====== problem with 148870
# Downloading sound with id 51667 [12/154]
# Downloading sound with id 51643 [13/154]
# Downloading sound with id 136971 [14/154]
# Downloading sound with id 136692 [15/154]
# Downloading sound with id 148879 [16/154]
# Downloading sound with id 136691 [17/154]
# Downloading sound with id 148877 [18/154]
# Downloading sound with id 161013 [19/154]
# Downloading sound with id 231275 [20/154]
# Downloading sound with id 263810 [21/154]
# Downloading sound with id 53469 [22/154]
# Downloading sound with id 17736 [23/154]
# Downloading sound with id 63092 [24/154]
# Downloading sound with id 424692 [25/154]
# Downloading sound with id 265034 [26/154]
# Downloading sound with id 7744 [27/154]
# Downloading sound with id 79232 [28/154]
# Downloading sound with id 105383 [29/154]
# Downloading sound with id 194993 [30/154]
# Downloading sound with id 223277 [31/154]
# Downloading sound with id 174624 [32/154]
# Downloading sound with id 206154 [33/154]
# Downloading sound with id 98779 [34/154]
# Downloading sound with id 275468 [35/154]
# Downloading sound with id 234107 [36/154]
# Downloading sound with id 97389 [37/154]
# Downloading sound with id 171473 [38/154]
# Downloading sound with id 236952 [39/154]
# Downloading sound with id 95892 [40/154]
# Downloading sound with id 207473 [41/154]
# Downloading sound with id 147182 [42/154]
# Downloading sound with id 400384 [43/154]
# Downloading sound with id 432846 [44/154]
# Downloading sound with id 434352 [45/154]
# Downloading sound with id 394959 [46/154]
# Downloading sound with id 402547 [47/154]
# Downloading sound with id 179900 [48/154]
# Downloading sound with id 267464 [49/154]
# Downloading sound with id 250725 [50/154]
# Downloading sound with id 86567 [51/154]
# Downloading sound with id 402801 [52/154]
# Downloading sound with id 317130 [53/154]
# Downloading sound with id 33256 [54/154]
# Downloading sound with id 169693 [55/154]
# Downloading sound with id 251635 [56/154]
# Downloading sound with id 367328 [57/154]
# Downloading sound with id 423398 [58/154]
# Downloading sound with id 428266 [59/154]
# Downloading sound with id 424844 [60/154]
# Downloading sound with id 412776 [61/154]
# Downloading sound with id 278295 [62/154]
# Downloading sound with id 192529 [63/154]
# Downloading sound with id 186253 [64/154]
# Downloading sound with id 46328 [65/154]
# Downloading sound with id 46325 [66/154]
# Downloading sound with id 94149 [67/154]
# Downloading sound with id 58334 [68/154]
# Downloading sound with id 259168 [69/154]
# Downloading sound with id 350324 [70/154]
# Downloading sound with id 132900 [71/154]
# Downloading sound with id 251473 [72/154]
# Downloading sound with id 60118 [73/154]
# Downloading sound with id 58168 [74/154]
# Downloading sound with id 44478 [75/154]
# Downloading sound with id 136052 [76/154]
# Downloading sound with id 341874 [77/154]
# Downloading sound with id 57744 [78/154]
# Downloading sound with id 55060 [79/154]
# Downloading sound with id 122814 [80/154]
# Downloading sound with id 401539 [81/154]
# Downloading sound with id 401993 [82/154]
# Downloading sound with id 130597 [83/154]
# Downloading sound with id 424844 [84/154]
# Downloading sound with id 72009 [85/154]
# Downloading sound with id 115088 [86/154]
# Downloading sound with id 205463 [87/154]
# Downloading sound with id 249776 [88/154]
# Downloading sound with id 75277 [89/154]
# Downloading sound with id 241698 [90/154]
# Downloading sound with id 69823 [91/154]
# Downloading sound with id 138469 [92/154]
# Downloading sound with id 240725 [93/154]
# Downloading sound with id 80980 [94/154]
# Downloading sound with id 101792 [95/154]
# Downloading sound with id 56730 [96/154]
# Downloading sound with id 210093 [97/154]
# Downloading sound with id 192178 [98/154]
# Downloading sound with id 17093 [99/154]
# Downloading sound with id 191337 [100/154]
# Downloading sound with id 365220 [101/154]
# Downloading sound with id 44311 [102/154]
# Downloading sound with id 371339 [103/154]
# Downloading sound with id 397336 [104/154]
# Downloading sound with id 161018 [105/154]
# Downloading sound with id 153425 [106/154]
# Downloading sound with id 239299 [107/154]
# Downloading sound with id 233261 [108/154]
# Downloading sound with id 169944 [109/154]
# Downloading sound with id 340747 [110/154]
# Downloading sound with id 329568 [111/154]
# Downloading sound with id 387459 [112/154]
# Downloading sound with id 407207 [113/154]
# Downloading sound with id 387460 [114/154]
# Downloading sound with id 397667 [115/154]
# Downloading sound with id 45352 [116/154]
# Downloading sound with id 31169 [117/154]
# Downloading sound with id 25270 [118/154]
# Downloading sound with id 32868 [119/154]
# Downloading sound with id 46228 [120/154]
# Downloading sound with id 49482 [121/154]
# Downloading sound with id 42811 [122/154]
# Downloading sound with id 39843 [123/154]
# Downloading sound with id 113148 [124/154]
# Downloading sound with id 407292 [125/154]
# Downloading sound with id 334980 [126/154]
# Downloading sound with id 211945 [127/154]
# Downloading sound with id 457258 [128/154]
# Downloading sound with id 32380 [129/154]
# Downloading sound with id 350655 [130/154]
# Downloading sound with id 383879 [131/154]
# Downloading sound with id 25450 [132/154]
# Downloading sound with id 326244 [133/154]
# Downloading sound with id 259630 [134/154]
# Downloading sound with id 203305 [135/154]
# Downloading sound with id 233018 [136/154]
# Downloading sound with id 407735 [137/154]
# Downloading sound with id 327497 [138/154]
# Downloading sound with id 366843 [139/154]
# Downloading sound with id 365965 [140/154]
# Downloading sound with id 145267 [141/154]
# Downloading sound with id 332183 [142/154]
# Downloading sound with id 369871 [143/154]
# Downloading sound with id 407499 [144/154]
# Downloading sound with id 389592 [145/154]
# Downloading sound with id 344238 [146/154]
# Downloading sound with id 24089 [147/154]
# Downloading sound with id 324427 [148/154]
# Downloading sound with id 81782 [149/154]
# Downloading sound with id 201942 [150/154]
# Downloading sound with id 346457 [151/154]
# Downloading sound with id 278295 [152/154]
# Downloading sound with id 192529 [153/154]
# Downloading sound with id 186253 [154/154]
# try again, with the problems
# Downloading sound with id 148870 [1/1]

# %%
#save sounds so I dont need to download again:
import pickle

def save_as_binary(element, filename = './files/no_name.file'):
    print('saving as pickle binary ...')
    with open(filename, "wb") as f:
        pickle.dump(element, f, pickle.HIGHEST_PROTOCOL)
    print('... file saved as', filename)

def load_as_binary(filename = './files/no_name.file'):
    with open(filename, "rb") as f:
        data = pickle.load(f)
    return data

save_as_binary(sounds, './temp/sounds.file')

sounds = load_as_binary('./temp/sounds.file')
# Out:
# saving as pickle binary ...
# ... file saved as ./temp/sounds.file

# %% [markdown]
# ### Download analysis by frames and save each one to a .npy file

# %%
problems = []

def get_analysis_frames_for_collection(sounds, folder_to_save='mfcc'):
    for count, sound in enumerate(sounds):
        try:
            print('Downloading analysis with id {0} [{1}/{2}]'.format(sound.id, count + 1, len(sounds)))
            analysis_frames = sound.get_analysis_frames()
            analysis_frames.lowlevel.mfcc # We only want mfccs at the moment 
            filename = os.path.join(folder_to_save, str(sound.id))
            np.save(filename, analysis_frames.lowlevel.mfcc) #save in file
        except:
            print("====== problem with", sound.id)
            problems.append(sound)
    print("====== DONE")
        
get_analysis_frames_for_collection(sounds)
# Out:
# Downloading analysis with id 415297 [1/155]
# Downloading analysis with id 403357 [2/155]
# Downloading analysis with id 41135 [3/155]
# Downloading analysis with id 58155 [4/155]
# Downloading analysis with id 403358 [5/155]
# Downloading analysis with id 428266 [6/155]
# Downloading analysis with id 403359 [7/155]
# Downloading analysis with id 403357 [8/155]
# Downloading analysis with id 405373 [9/155]
# Downloading analysis with id 397092 [10/155]
# Downloading analysis with id 148870 [11/155]
# Downloading analysis with id 51667 [12/155]
# Downloading analysis with id 51643 [13/155]
# Downloading analysis with id 136971 [14/155]
# Downloading analysis with id 136692 [15/155]
# Downloading analysis with id 148879 [16/155]
# Downloading analysis with id 136691 [17/155]
# Downloading analysis with id 148877 [18/155]
# Downloading analysis with id 161013 [19/155]
# Downloading analysis with id 231275 [20/155]
# Downloading analysis with id 263810 [21/155]
# Downloading analysis with id 53469 [22/155]
# Downloading analysis with id 17736 [23/155]
# Downloading analysis with id 63092 [24/155]
# Downloading analysis with id 424692 [25/155]
# Downloading analysis with id 265034 [26/155]
# Downloading analysis with id 7744 [27/155]
# Downloading analysis with id 79232 [28/155]
# Downloading analysis with id 105383 [29/155]
# Downloading analysis with id 194993 [30/155]
# Downloading analysis with id 223277 [31/155]
# Downloading analysis with id 174624 [32/155]
# Downloading analysis with id 206154 [33/155]
# Downloading analysis with id 98779 [34/155]
# Downloading analysis with id 275468 [35/155]
# Downloading analysis with id 234107 [36/155]
# Downloading analysis with id 97389 [37/155]
# Downloading analysis with id 171473 [38/155]
# Downloading analysis with id 236952 [39/155]
# Downloading analysis with id 95892 [40/155]
# Downloading analysis with id 207473 [41/155]
# Downloading analysis with id 147182 [42/155]
# Downloading analysis with id 400384 [43/155]
# Downloading analysis with id 432846 [44/155]
# Downloading analysis with id 434352 [45/155]
# Downloading analysis with id 394959 [46/155]
# Downloading analysis with id 402547 [47/155]
# Downloading analysis with id 179900 [48/155]
# Downloading analysis with id 267464 [49/155]
# Downloading analysis with id 250725 [50/155]
# Downloading analysis with id 86567 [51/155]
# Downloading analysis with id 402801 [52/155]
# Downloading analysis with id 317130 [53/155]
# Downloading analysis with id 33256 [54/155]
# Downloading analysis with id 169693 [55/155]
# Downloading analysis with id 251635 [56/155]
# Downloading analysis with id 367328 [57/155]
# Downloading analysis with id 423398 [58/155]
# ====== problem with 423398
# Downloading analysis with id 428266 [59/155]
# Downloading analysis with id 424844 [60/155]
# Downloading analysis with id 412776 [61/155]
# Downloading analysis with id 278295 [62/155]
# Downloading analysis with id 192529 [63/155]
# Downloading analysis with id 186253 [64/155]
# Downloading analysis with id 46328 [65/155]
# Downloading analysis with id 46325 [66/155]
# Downloading analysis with id 94149 [67/155]
# Downloading analysis with id 58334 [68/155]
# Downloading analysis with id 259168 [69/155]
# Downloading analysis with id 350324 [70/155]
# Downloading analysis with id 132900 [71/155]
# Downloading analysis with id 251473 [72/155]
# Downloading analysis with id 60118 [73/155]
# Downloading analysis with id 58168 [74/155]
# Downloading analysis with id 44478 [75/155]
# Downloading analysis with id 136052 [76/155]
# Downloading analysis with id 341874 [77/155]
# Downloading analysis with id 57744 [78/155]
# Downloading analysis with id 55060 [79/155]
# Downloading analysis with id 122814 [80/155]
# Downloading analysis with id 401539 [81/155]
# Downloading analysis with id 401993 [82/155]
# Downloading analysis with id 130597 [83/155]
# Downloading analysis with id 424844 [84/155]
# Downloading analysis with id 72009 [85/155]
# Downloading analysis with id 115088 [86/155]
# Downloading analysis with id 205463 [87/155]
# Downloading analysis with id 249776 [88/155]
# Downloading analysis with id 75277 [89/155]
# Downloading analysis with id 241698 [90/155]
# Downloading analysis with id 69823 [91/155]
# Downloading analysis with id 138469 [92/155]
# Downloading analysis with id 240725 [93/155]
# Downloading analysis with id 80980 [94/155]
# Downloading analysis with id 101792 [95/155]
# Downloading analysis with id 56730 [96/155]
# Downloading analysis with id 210093 [97/155]
# Downloading analysis with id 192178 [98/155]
# Downloading analysis with id 17093 [99/155]
# Downloading analysis with id 191337 [100/155]
# Downloading analysis with id 365220 [101/155]
# Downloading analysis with id 44311 [102/155]
# Downloading analysis with id 371339 [103/155]
# Downloading analysis with id 397336 [104/155]
# Downloading analysis with id 161018 [105/155]
# Downloading analysis with id 153425 [106/155]
# Downloading analysis with id 239299 [107/155]
# Downloading analysis with id 233261 [108/155]
# Downloading analysis with id 169944 [109/155]
# Downloading analysis with id 340747 [110/155]
# Downloading analysis with id 329568 [111/155]
# Downloading analysis with id 387459 [112/155]
# Downloading analysis with id 407207 [113/155]
# Downloading analysis with id 387460 [114/155]
# Downloading analysis with id 397667 [115/155]
# Downloading analysis with id 45352 [116/155]
# Downloading analysis with id 31169 [117/155]
# Downloading analysis with id 25270 [118/155]
# Downloading analysis with id 32868 [119/155]
# Downloading analysis with id 46228 [120/155]
# Downloading analysis with id 49482 [121/155]
# Downloading analysis with id 42811 [122/155]
# Downloading analysis with id 39843 [123/155]
# Downloading analysis with id 113148 [124/155]
# Downloading analysis with id 407292 [125/155]
# Downloading analysis with id 334980 [126/155]
# Downloading analysis with id 211945 [127/155]
# Downloading analysis with id 457258 [128/155]
# Downloading analysis with id 32380 [129/155]
# Downloading analysis with id 350655 [130/155]
# Downloading analysis with id 383879 [131/155]
# Downloading analysis with id 25450 [132/155]
# Downloading analysis with id 326244 [133/155]
# Downloading analysis with id 259630 [134/155]
# Downloading analysis with id 203305 [135/155]
# Downloading analysis with id 233018 [136/155]
# Downloading analysis with id 407735 [137/155]
# Downloading analysis with id 327497 [138/155]
# Downloading analysis with id 366843 [139/155]
# Downloading analysis with id 365965 [140/155]
# Downloading analysis with id 145267 [141/155]
# Downloading analysis with id 332183 [142/155]
# Downloading analysis with id 369871 [143/155]
# Downloading analysis with id 407499 [144/155]
# Downloading analysis with id 389592 [145/155]
# Downloading analysis with id 344238 [146/155]
# Downloading analysis with id 24089 [147/155]
# Downloading analysis with id 324427 [148/155]
# Downloading analysis with id 81782 [149/155]
# Downloading analysis with id 201942 [150/155]
# Downloading analysis with id 346457 [151/155]
# Downloading analysis with id 278295 [152/155]
# Downloading analysis with id 192529 [153/155]
# Downloading analysis with id 186253 [154/155]
# Downloading analysis with id 148870 [155/155]

# %% [markdown]
# ## Create sounds_metadata.json for use with web-visu
# ### It follows this structure:
# {
#     "131086": {
#         "username": "ecfike",
#         "preview": "https://freesound.org/data/previews/131/131086_2337290-lq.ogg",
#         "name": "What's Up Yall 1.wav",
#         "tags": ["boy", "male", "whats", "up", "whats-up-yall", "words", "word", "voice", "yall", "man"]
#     }
# }

# %%
import json

def save_to_json(element, filename = './files/no_name.json'):
    print('saving to json ...')
    with open(filename, 'w') as fp:
        json.dump(element, fp, sort_keys=True, indent=4) #pretty json
    print('... file saved as', filename)

    
def create_sounds_metadata(sounds):
    sounds_metadata = {}
    for sound in sounds:
        sounds_metadata[str(sound.id)] = {
            "username": sound.username,
            "preview": sound.previews.preview_lq_ogg,
            "name": sound.name,
            "tags": sound.tags 
        }
    return sounds_metadata

sounds_metadata = create_sounds_metadata(sounds)

save_to_json(sounds_metadata, './files/sounds_metadata_own.json')
# Out:
# saving to json ...
# ... file saved as ./files/sounds_metadata_own.json
